# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/MachineLearningNotebooks/how-to-use-azureml/ml-frameworks/keras/train-hyperparameter-tune-deploy-with-keras/train-hyperparameter-tune-deploy-with-keras.png)

# %% [markdown]
# Let's get started. First let's import some Python libraries.

# %%
# %matplotlib inline
import numpy as np
import os
import matplotlib.pyplot as plt
from glob import glob
import librosa
import librosa.display
from path import Path

# %%
import azureml
from azureml.core import Workspace

# check core SDK version number
print("Azure ML SDK Version: ", azureml.core.VERSION)
# Out:
# Azure ML SDK Version:  1.20.0

# %% [markdown]
# ## Initialize workspace
# Initialize a [Workspace](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#workspace) object from the existing workspace you created in the Prerequisites step. `Workspace.from_config()` creates a workspace object from the details stored in `config.json`.

# %%
ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep='\n')
# Out:
# Workspace name: aiforgoodgp1
# Azure region: eastus
# Subscription id: 7f1957e6-ab9f-44e4-82eb-9e4b6cb8a45e
# Resource group: project15group1

# %% [markdown]
# Use the `register()` method to register datasets to your workspace so they can be shared with others, reused across various experiments, and referred to by name in your training script.
# You can try get the dataset first to see if it's already registered.

# %% [markdown]
# ## Register the model

# %% [markdown]
# We can then register the folder (and all files in it) as a model named `aiforgoodp15` under the workspace for deployment.

# %%
from azureml.core.model import Model
# Tip: When model_path is set to a directory, you can use the child_paths parameter to include
#      only some of the files from the directory
model = Model.register(model_path = "./output",
                       model_name = "aiforgoodp15",
                       description = "AI for good",
                       workspace = ws)

# %% [markdown]
# ## Deploy the model in ACI
# Now we are ready to deploy the model as a web service running in Azure Container Instance [ACI](https://azure.microsoft.com/en-us/services/container-instances/). Azure Machine Learning accomplishes this by constructing a Docker image with the scoring logic and model baked in.
# ### Create score.py
# First, we will create a scoring script that will be invoked by the web service call.
#
# * Note that the scoring script must have two required functions, `init()` and `run(input_data)`.
#   * In `init()` function, you typically load the model into a global object. This function is executed only once when the Docker container is started.
#   * In `run(input_data)` function, the model is used to predict a value based on the input data. The input and output to `run` typically use JSON as serialization and de-serialization format but you are not limited to that.

# %%
import json
import numpy as np
import os
from keras.models import model_from_json
from tensorflow import keras
from azureml.core.model import Model

def init():
  
    global model
    global train_mean
    global classes

    classes= {1: 'car_horn', 3: 'dog_bark', 2: 'children_playing', 
          0: 'air_conditioner', 5: 'engine_idling', 7: 'jackhammer', 
          6: 'gun_shot', 9: 'street_music', 4: 'drilling', 8: 'siren', 10: 'Elephant'}
    
    #Get the path to where the model is stored in AML
    model_1_path = Model.get_model_path('aiforgoodp15')

    #Build out the complete path and file name
    modelname  = '/'+'spectrogram_save.h5'
    model_complete = model_1_path + modelname

    #Load the model from AML model registry
    model = keras.models.load_model(model_complete,compile=False)
    #model = keras.models.load_model('./output/spectrogram_save.h5')

    stored_array_name = '/'+'file.npz'
    stored_array_complete = model_1_path + stored_array_name

    loaded = np.load(stored_array_complete)
    #loaded = np.load('./output/file.npz')
    train_mean = loaded['train_mean']
    
def run(audio_data):

    filename,name = audio_data,audio_data.split('/')[-1]
    
    #Create the spectrogram
    plt.interactive(False)
    clip, sample_rate = librosa.load(filename, sr=None)
    fig = plt.figure(figsize=[0.72,0.72])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y=clip, sr=sample_rate)
    librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
    filename  = Path('./' + name + '.jpg')
    fig.savefig(filename, dpi=400, bbox_inches='tight',pad_inches=0)
    plt.close()    
    fig.clf()
    plt.close(fig)
    plt.close('all')
    
        
    #Convert the spectrogram to a format for the model can use
    test= np.array(glob(filename))
    img_size=32
    Input = np.stack([np.asarray(Image.open(l).convert('RGB').resize((img_size, img_size))) for l in test], axis=0)
    
    ##Predict the class using the model
    output = model.predict((Input - train_mean[None,None,None,:])/256.)
    preds = [np.argmax(l) for l in output]
    cls_preds = [classes[l] for l in preds]
    
    #Return the results of the prediction 
    return (preds,cls_preds)

# %%
init()

# %%
run('./nn01a_20180203_1230-Copy1.wav')
# Out:
# ([6], ['gun_shot'])

# %%
# %%writefile score.py
import json
import numpy as np
import os
from keras.models import model_from_json
from tensorflow import keras
from azureml.core.model import Model

def init():
  
    global model
    global train_mean
    global classes

    classes= {1: 'car_horn', 3: 'dog_bark', 2: 'children_playing', 
          0: 'air_conditioner', 5: 'engine_idling', 7: 'jackhammer', 
          6: 'gun_shot', 9: 'street_music', 4: 'drilling', 8: 'siren', 10: 'Elephant'}
    
    #Get the path to where the model is stored in AML
    model_1_path = Model.get_model_path('aiforgoodp15')

    #Build out the complete path and file name
    modelname  = '/'+'spectrogram_save.h5'
    model_complete = model_1_path + modelname

    #Load the model from AML model registry
    model = keras.models.load_model(model_complete,compile=False)
    #model = keras.models.load_model('./output/spectrogram_save.h5')

    stored_array_name = '/'+'file.npz'
    stored_array_complete = model_1_path + stored_array_name

    loaded = np.load(stored_array_complete)
    #loaded = np.load('./output/file.npz')
    train_mean = loaded['train_mean']
    
def run(audio_data):

    filename,name = audio_data,audio_data.split('/')[-1]
    
    #Create the spectrogram
    plt.interactive(False)
    clip, sample_rate = librosa.load(filename, sr=None)
    fig = plt.figure(figsize=[0.72,0.72])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y=clip, sr=sample_rate)
    librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
    filename  = Path('./' + name + '.jpg')
    fig.savefig(filename, dpi=400, bbox_inches='tight',pad_inches=0)
    plt.close()    
    fig.clf()
    plt.close(fig)
    plt.close('all')
    
        
    #Convert the spectrogram to a format for the model can use
    test= np.array(glob(filename))
    img_size=32
    Input = np.stack([np.asarray(Image.open(l).convert('RGB').resize((img_size, img_size))) for l in test], axis=0)
    
    ##Predict the class using the model
    output = model.predict((Input - train_mean[None,None,None,:])/256.)
    preds = [np.argmax(l) for l in output]
    cls_preds = [classes[l] for l in preds]
    
    #Return the results of the prediction 
    return (preds,cls_preds)
# Out:
# Overwriting score.py

# %% [markdown]
# ### Create myenv.yml
# We also need to create an environment file so that Azure Machine Learning can install the necessary packages in the Docker image which are required by your scoring script. In this case, we need to specify conda packages `tensorflow` and `keras`.

# %%
# !pip freeze
# Out:
# absl-py==0.11.0
# adal==1.2.5
# aiohttp==3.7.3
# aiohttp-cors==0.7.0
# aioredis==1.3.1
# alembic==1.4.1
# ansiwrap==0.8.4
# antlr4-python3-runtime==4.7.2
# appdirs==1.4.4
# applicationinsights==0.11.9
# argcomplete==1.12.2
# argon2-cffi==20.1.0
# astor==0.8.1
# astroid==2.4.2
# astunparse==1.6.3
# async-timeout==3.0.1
# atari-py==0.2.6
# attrs==20.3.0
# audioread==2.1.9
# autopep8==1.5.4
# azure-appconfiguration==1.1.1
# azure-batch==10.0.0
# azure-cli==2.17.1
# azure-cli-core==2.17.1
# azure-cli-telemetry==1.0.6
# azure-common==1.1.26
# azure-core==1.9.0
# azure-cosmos==3.2.0
# azure-datalake-store==0.0.51
# azure-functions-devops-build==0.0.22
# azure-graphrbac==0.61.1
# azure-identity==1.4.1
# azure-keyvault==1.1.0
# azure-keyvault-administration==4.0.0b2
# azure-loganalytics==0.1.0
# azure-mgmt-advisor==2.0.1
# azure-mgmt-apimanagement==0.2.0
# azure-mgmt-appconfiguration==0.6.0
# azure-mgmt-applicationinsights==0.1.1
# azure-mgmt-authorization==0.61.0
# azure-mgmt-batch==9.0.0
# azure-mgmt-batchai==2.0.0
# azure-mgmt-billing==1.0.0
# azure-mgmt-botservice==0.2.0
# azure-mgmt-cdn==5.2.0
# azure-mgmt-cognitiveservices==6.3.0
# azure-mgmt-compute==18.0.0
# azure-mgmt-consumption==2.0.0
# azure-mgmt-containerinstance==1.5.0
# azure-mgmt-containerregistry==2.8.0
# azure-mgmt-containerservice==9.4.0
# azure-mgmt-core==1.2.1
# azure-mgmt-cosmosdb==1.0.0
# azure-mgmt-databoxedge==0.2.0
# azure-mgmt-datalake-analytics==0.2.1
# azure-mgmt-datalake-nspkg==3.0.1
# azure-mgmt-datalake-store==0.5.0
# azure-mgmt-datamigration==0.1.0
# azure-mgmt-deploymentmanager==0.2.0
# azure-mgmt-devtestlabs==4.0.0
# azure-mgmt-dns==2.1.0
# azure-mgmt-eventgrid==3.0.0rc7
# azure-mgmt-eventhub==4.1.0
# azure-mgmt-hdinsight==2.0.0
# azure-mgmt-imagebuilder==0.4.0
# azure-mgmt-iotcentral==3.0.0
# azure-mgmt-iothub==0.12.0
# azure-mgmt-iothubprovisioningservices==0.2.0
# azure-mgmt-keyvault==2.2.0
# azure-mgmt-kusto==0.3.0
# azure-mgmt-loganalytics==0.7.0
# azure-mgmt-managedservices==1.0.0
# azure-mgmt-managementgroups==0.2.0
# azure-mgmt-maps==0.1.0
# azure-mgmt-marketplaceordering==0.2.1
# azure-mgmt-media==2.2.0
# azure-mgmt-monitor==0.11.0
# azure-mgmt-msi==0.2.0
# azure-mgmt-netapp==0.14.0
# azure-mgmt-network==17.0.0
# azure-mgmt-nspkg==3.0.2
# azure-mgmt-policyinsights==0.5.0
# azure-mgmt-privatedns==0.1.0
# azure-mgmt-rdbms==3.1.0rc1
# azure-mgmt-recoveryservices==0.4.0
# azure-mgmt-recoveryservicesbackup==0.6.0
# azure-mgmt-redhatopenshift==0.1.0
# azure-mgmt-redis==7.0.0rc2
# azure-mgmt-relay==0.1.0
# azure-mgmt-reservations==0.6.0
# azure-mgmt-resource==12.0.0
# azure-mgmt-search==2.1.0
# azure-mgmt-security==0.6.0
# azure-mgmt-servicebus==0.6.0
# azure-mgmt-servicefabric==0.5.0
# azure-mgmt-signalr==0.4.0
# azure-mgmt-sql==0.21.0
# azure-mgmt-sqlvirtualmachine==0.5.0
# azure-mgmt-storage==11.2.0
# azure-mgmt-synapse==0.5.0
# azure-mgmt-trafficmanager==0.51.0
# azure-mgmt-web==0.48.0
# azure-multiapi-storage==0.5.2
# azure-nspkg==3.0.2
# azure-storage-blob==12.6.0
# azure-storage-common==1.4.2
# azure-storage-queue==12.1.4
# azure-synapse-accesscontrol==0.2.0
# azure-synapse-artifacts==0.3.0
# azure-synapse-spark==0.2.0
# azureml-accel-models==1.20.0
# azureml-automl-core==1.20.0
# azureml-automl-runtime==1.20.0
# azureml-cli-common==1.20.0
# azureml-contrib-dataset==1.20.0
# azureml-contrib-fairness==1.20.0
# azureml-contrib-gbdt==1.20.0
# azureml-contrib-interpret==1.20.0
# azureml-contrib-notebook==1.20.0
# azureml-contrib-pipeline-steps==1.20.0
# azureml-contrib-reinforcementlearning==1.20.0
# azureml-contrib-server==1.20.0
# azureml-contrib-services==1.20.0
# azureml-core==1.20.0
# azureml-datadrift==1.20.0
# azureml-dataprep==2.7.3
# azureml-dataprep-native==27.0.0
# azureml-dataprep-rslex==1.5.0
# azureml-dataset-runtime==1.20.0
# azureml-defaults==1.20.0
# azureml-explain-model==1.20.0
# azureml-interpret==1.20.0
# azureml-mlflow==1.20.0.post1
# azureml-model-management-sdk==1.0.1b6.post1
# azureml-opendatasets==1.20.0
# azureml-pipeline==1.20.0
# azureml-pipeline-core==1.20.0
# azureml-pipeline-steps==1.20.0
# azureml-samples @ file:///mnt/jupyter-azsamples
# azureml-sdk==1.20.0
# azureml-telemetry==1.20.0
# azureml-tensorboard==1.20.0
# azureml-train==1.20.0
# azureml-train-automl==1.20.0
# azureml-train-automl-client==1.20.0
# azureml-train-automl-runtime==1.20.0
# azureml-train-core==1.20.0
# azureml-train-restclients-hyperdrive==1.20.0
# azureml-widgets==1.20.0
# backcall==0.2.0
# backports.functools-lru-cache==1.6.1
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# bcrypt==3.2.0
# beautifulsoup4==4.9.3
# bleach==3.2.1
# blessings==1.7
# blis==0.2.4
# bokeh==2.2.3
# boto==2.49.0
# boto3==1.15.18
# botocore==1.18.18
# Bottleneck==1.3.2
# cached-property==1.5.2
# cachetools==4.2.0
# certifi==2020.12.5
# cffi==1.14.4
# chardet==4.0.0
# click==7.1.2
# cloudpickle==1.6.0
# colorama==0.4.4
# colorful==0.5.4
# configparser==3.7.4
# contextlib2==0.6.0.post1
# contextvars==2.4
# convertdate @ file:///home/conda/feedstock_root/build_artifacts/convertdate_1605102623033/work
# coremltools @ git+https://github.com/apple/coremltools@13c064ed99ab1da7abea0196e4ddf663ede48aad
# cryptography==3.3.1
# cycler==0.10.0
# cymem==2.0.5
# Cython @ file:///tmp/build/80754af9/cython_1594831565616/work
# databricks-cli==0.14.1
# dataclasses==0.8
# decorator==4.4.2
# defusedxml==0.6.0
# dill==0.3.3
# distro==1.5.0
# dm-tree==0.1.5
# docker==4.4.1
# dotnetcore2==2.1.20
# en-core-web-sm @ https://aka.ms/automl-resources/packages/en_core_web_sm-2.1.0.tar.gz
# encrypted-inference==0.9
# entrypoints==0.3
# enum34==1.1.10
# fabric==2.5.0
# fairlearn==0.4.6
# fastai==1.0.61
# fastprogress==1.0.0
# fbprophet==0.5
# filelock==3.0.12
# fire==0.3.1
# flake8==3.8.4
# Flask==1.0.3
# Flask-Cors==3.0.10
# flatbuffers==1.12
# fusepy==3.0.1
# future==0.18.2
# gast==0.3.3
# gensim==3.8.3
# gevent==20.12.1
# gitdb==4.0.5
# GitPython==3.1.12
# google-api-core==1.24.1
# google-auth==1.24.0
# google-auth-oauthlib==0.4.2
# google-pasta==0.2.0
# googleapis-common-protos==1.52.0
# gpustat==0.6.0
# greenlet==0.4.17
# grpcio==1.34.0
# gunicorn==19.9.0
# gym==0.18.0
# h5py==2.10.0
# hiredis==1.1.0
# holidays==0.9.11
# horovod==0.19.1
# humanfriendly==8.2
# idna==2.10
# idna-ssl==1.1.0
# imageio==2.9.0
# immutables==0.14
# importlib-metadata==3.3.0
# interpret-community==0.15.4
# interpret-core==0.2.1
# invoke==1.5.0
# ipykernel==5.4.3
# ipython==7.16.1
# ipython-genutils==0.2.0
# ipywidgets==7.6.3
# isodate==0.6.0
# isort==5.7.0
# itsdangerous==1.1.0
# javaproperties==0.5.1
# jedi==0.18.0
# jeepney==0.6.0
# Jinja2==2.11.2
# jmespath==0.10.0
# joblib==0.14.1
# jsmin==2.2.2
# json-logging-py==0.2
# json5==0.9.5
# jsondiff==1.2.0
# jsonpickle==1.4.2
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==6.1.11
# jupyter-console==6.2.0
# jupyter-core==4.7.0
# jupyter-server-proxy==1.5.3
# jupyterlab==2.1.4
# jupyterlab-nvdashboard==0.4.0
# jupyterlab-server==1.2.0
# jupyterlab-widgets==1.0.0
# jupytext==1.6.0
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.2
# keras2onnx==1.6.0
# kiwisolver==1.3.1
# knack==0.7.2
# lazy-object-proxy==1.4.3
# liac-arff==2.5.0
# librosa==0.8.0
# lightgbm==2.3.0
# llvmlite==0.35.0
# lunardate==0.2.0
# lz4==3.1.1
# Mako==1.1.3
# Markdown==3.3.3
# markdown-it-py==0.5.8
# MarkupSafe==1.1.1
# matplotlib==3.2.1
# mccabe==0.6.1
# mistune==0.8.4
# mkl-fft==1.2.0
# mkl-random==1.1.0
# mkl-service==2.3.0
# mlflow==1.13.1
# mock==4.0.3
# msal==1.8.0
# msal-extensions==0.2.2
# msgpack==1.0.2
# msrest==0.6.19
# msrestazure==0.6.4
# multidict==5.1.0
# murmurhash==1.0.5
# nbconvert==5.6.1
# nbformat==5.0.8
# ndg-httpsclient==0.5.1
# networkx==2.5
# nimbusml==1.8.0
# notebook==6.1.6
# numba==0.52.0
# numexpr==2.7.2
# numpy==1.18.5
# nvidia-ml-py3==7.352.0
# oauthlib==3.1.0
# olefile==0.46
# onnx==1.7.0
# onnxconverter-common==1.6.0
# onnxmltools==1.4.1
# onnxruntime==1.3.0
# opencensus==0.7.11
# opencensus-context==0.1.2
# opencv-python==4.5.1.48
# opencv-python-headless==4.3.0.36
# opt-einsum==3.3.0
# packaging==20.8
# pandas==0.25.3
# pandas-ml==0.6.1
# pandocfilters==1.4.3
# papermill==1.2.1
# paramiko==2.7.2
# parso==0.8.1
# path==15.1.2
# pathspec==0.8.1
# patsy==0.5.1
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==6.2.1
# pkginfo==1.6.1
# plac==0.9.6
# pluggy==0.13.1
# pmdarima==1.1.1
# pooch==1.3.0
# portalocker==1.7.1
# preshed==2.0.1
# prometheus-client==0.9.0
# prometheus-flask-exporter==0.18.1
# prompt-toolkit==3.0.10
# protobuf==3.14.0
# psutil==5.8.0
# psycopg2==2.8.4
# ptyprocess==0.7.0
# py-cpuinfo==5.0.0
# py-spy==0.3.3
# py4j==0.10.9
# pyarrow==1.0.1
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycocotools==2.0.0
# pycodestyle==2.6.0
# pycparser @ file:///tmp/build/80754af9/pycparser_1594388511720/work
# pydocstyle==5.1.1
# pyflakes==2.2.0
# pyglet==1.5.0
# Pygments==2.7.4
# PyJWT==1.7.1
# pylint==2.6.0
# PyMeeus @ file:///home/conda/feedstock_root/build_artifacts/pymeeus_1589222711601/work
# PyNaCl==1.4.0
# pynvml==8.0.4
# pyodbc===4.0.0-unsupported
# pyOpenSSL==19.1.0
# pyparsing==2.4.7
# pyrsistent==0.17.3
# pyspark==3.0.1
# pystan==2.19.0.0
# python-dateutil==2.8.1
# python-editor==1.0.4
# python-jsonrpc-server==0.4.0
# python-language-server==0.35.0
# pytorch-transformers==1.0.0
# pytz==2020.5
# PyWavelets==1.1.1
# PyYAML==5.3.1
# pyzmq==20.0.0
# qtconsole==5.0.1
# QtPy==1.9.0
# QuantLib==1.20
# querystring-parser==1.2.4
# ray==1.1.0
# redis==3.5.3
# regex==2020.11.13
# requests==2.25.1
# requests-oauthlib==1.3.0
# resampy==0.2.2
# rope==0.18.0
# rsa==4.7
# ruamel.yaml==0.16.12
# ruamel.yaml.clib==0.2.2
# s3transfer==0.3.3
# sacremoses==0.0.43
# scikit-image==0.17.2
# scikit-learn==0.22.2.post1
# scipy @ file:///tmp/build/80754af9/scipy_1597686625380/work
# scp==0.13.3
# scrapbook==0.5.0
# SecretStorage==3.3.0
# Send2Trash==1.5.0
# sentencepiece==0.1.95
# setuptools-git==1.2
# shap==0.34.0
# simpervisor==0.4
# sip==4.19.24
# six==1.15.0
# skl2onnx==1.4.9
# sklearn==0.0
# sklearn-pandas==1.7.0
# smart-open==1.9.0
# smmap==3.0.4
# snowballstemmer==2.0.0
# SoundFile==0.10.3.post1
# soupsieve==2.1
# spacy==2.1.8
# SQLAlchemy==1.3.22
# sqlparse==0.4.1
# srsly==1.0.5
# sshtunnel==0.1.5
# statsmodels==0.10.2
# tabulate==0.8.7
# tenacity==6.3.1
# tensorboard==2.4.0
# tensorboard-plugin-wit==1.7.0
# tensorboardX==2.1
# tensorflow==2.4.0
# tensorflow-estimator==2.4.0
# tensorflow-gpu==2.1.0
# termcolor==1.1.0
# terminado==0.9.2
# testpath==0.4.4
# textwrap3==0.9.2
# thinc==7.0.8
# threadpoolctl @ file:///tmp/tmp9twdgx9k/threadpoolctl-2.1.0-py3-none-any.whl
# tifffile==2020.9.3
# tokenizers==0.9.4
# toml==0.10.2
# torch==1.6.0
# torchvision==0.7.0
# tornado==6.1
# tqdm==4.55.1
# traitlets==4.3.3
# transformers==4.1.1
# typed-ast==1.4.2
# typing-extensions==3.7.4.3
# ujson==4.0.1
# urllib3==1.25.11
# vsts==0.1.25
# vsts-cd-manager==1.0.2
# waitress==1.4.4
# wasabi==0.8.0
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1600965781394/work
# webencodings==0.5.1
# websocket-client==0.57.0
# websockets==8.1
# Werkzeug==1.0.1
# widgetsnbextension==3.5.1
# wrapt==1.12.1
# xgboost==0.90
# xmltodict==0.12.0
# yapf==0.30.0
# yarl==1.6.3
# zipp==3.4.0
# zope.event==4.5.0
# zope.interface==5.2.0

# %%
from azureml.core.conda_dependencies import CondaDependencies

cd = CondaDependencies.create()
cd.add_conda_package('h5py<=2.10.0')
cd.add_conda_package('keras<=2.3.1')
cd.add_conda_package('Pillow==6.2.1')
cd.add_conda_package('librosa==0.8.0')
cd.add_conda_package('matplotlib==3.2.1')
cd.add_pip_package('tensorflow==2.4.0')
cd.save_to_file(base_directory='./', conda_file_path='myenv.yml')
print(cd.serialize_to_string())
# Out:
# # Conda environment specification. The dependencies defined in this file will
# # be automatically provisioned for runs with userManagedDependencies=False.
#
# # Details about the Conda environment file format:
# # https://conda.io/docs/user-guide/tasks/manage-environments.html#create-env-file-manually
#
# name: project_environment
# dependencies:
#   # The python interpreter version.
#   # Currently Azure ML only supports 3.5.2 and later.
# - python=3.6.2
#
# - pip:
#   - azureml-defaults~=1.20.0
#   - tensorflow==2.4.0
# - h5py<=2.10.0
# - keras<=2.3.1
# - Pillow==6.2.1
# - librosa==0.8.0
# - matplotlib==3.2.1
# channels:
# - anaconda
# - conda-forge

# %% [markdown]
# ### Deploy to ACI
# We are almost ready to deploy. Create the inference configuration and deployment configuration and deploy to ACI. This cell will run for about 7-8 minutes.

# %%
from azureml.core.webservice import AciWebservice
from azureml.core.model import InferenceConfig
from azureml.core.model import Model
from azureml.core.environment import Environment

myenv = Environment.from_conda_specification(name="myenv", file_path="myenv.yml")
myenv = myenv.register(ws)
bld = myenv.build(ws)
bld.wait_for_completion(show_output=True)
# Out:
# Image Build Status: Running
#
# 2021/02/23 22:37:10 Downloading source code...
# 2021/02/23 22:37:12 Finished downloading source code
# 2021/02/23 22:37:12 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/02/23 22:37:13 Successfully set up Docker network: acb_default_network
# 2021/02/23 22:37:13 Setting up Docker configuration...
# 2021/02/23 22:37:14 Successfully set up Docker configuration
# 2021/02/23 22:37:14 Logging in to registry: aiforgoodgp1.azurecr.io
# 2021/02/23 22:37:15 Successfully logged into aiforgoodgp1.azurecr.io
# 2021/02/23 22:37:15 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/02/23 22:37:15 Scanning for dependencies...
# 2021/02/23 22:37:16 Successfully scanned dependencies
# 2021/02/23 22:37:16 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# baf7ab26f516: Waiting
# 181182e3c9cf: Waiting
# 05895bb28c18: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# d584ef274e55: Waiting
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# Digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#  ---> 138ae4912094
# Step 2/18 : USER root
#  ---> Running in 85565b66fc2b
# Removing intermediate container 85565b66fc2b
#  ---> d43cc2d4ecf8
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 43d2d961aaf3
# Removing intermediate container 43d2d961aaf3
#  ---> c4f451e023d9
# Step 4/18 : WORKDIR /
#  ---> Running in 1663a46b127a
# Removing intermediate container 1663a46b127a
#  ---> a439f13465fe
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 7fcd3ddb1cfb
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 8dc9eb7041a1
# Removing intermediate container 8dc9eb7041a1
#  ---> 9d1ec711e34a
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 53eb062992e1
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 1c6cf3d53c82
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# tensorflow-estimator | 272 KB    |            |   0%
# tensorflow-estimator | 272 KB    | 5          |   6%
# tensorflow-estimator | 272 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# chardet-3.0.4        | 197 KB    |            |   0%
# chardet-3.0.4        | 197 KB    | ########## | 100%
#
# python_abi-3.6       | 4 KB      |            |   0%
# python_abi-3.6       | 4 KB      | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   2%
# mkl-2019.4           | 204.1 MB  | 5          |   6%
# mkl-2019.4           | 204.1 MB  | 9          |  10%
# mkl-2019.4           | 204.1 MB  | #2         |  13%
# mkl-2019.4           | 204.1 MB  | #5         |  15%
# mkl-2019.4           | 204.1 MB  | #9         |  19%
# mkl-2019.4           | 204.1 MB  | ##2        |  23%
# mkl-2019.4           | 204.1 MB  | ##7        |  27%
# mkl-2019.4           | 204.1 MB  | ###        |  31%
# mkl-2019.4           | 204.1 MB  | ###3       |  34%
# mkl-2019.4           | 204.1 MB  | ###7       |  37%
# mkl-2019.4           | 204.1 MB  | ####       |  41%
# mkl-2019.4           | 204.1 MB  | ####4      |  44%
# mkl-2019.4           | 204.1 MB  | ####7      |  47%
# mkl-2019.4           | 204.1 MB  | #####      |  51%
# mkl-2019.4           | 204.1 MB  | #####3     |  54%
# mkl-2019.4           | 204.1 MB  | #####7     |  58%
# mkl-2019.4           | 204.1 MB  | ######1    |  61%
# mkl-2019.4           | 204.1 MB  | ######4    |  65%
# mkl-2019.4           | 204.1 MB  | ######7    |  68%
# mkl-2019.4           | 204.1 MB  | #######1   |  71%
# mkl-2019.4           | 204.1 MB  | #######4   |  74%
# mkl-2019.4           | 204.1 MB  | #######7   |  77%
# mkl-2019.4           | 204.1 MB  | ########   |  80%
# mkl-2019.4           | 204.1 MB  | ########3  |  83%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# llvmlite-0.34.0      | 319 KB    |            |   0%
# llvmlite-0.34.0      | 319 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #####7     |  58%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# brotlipy-0.7.0       | 348 KB    |            |   0%
# brotlipy-0.7.0       | 348 KB    | ########## | 100%
#
# zipp-3.3.1           | 11 KB     |            |   0%
# zipp-3.3.1           | 11 KB     | ########## | 100%
#
# cryptography-2.3.1   | 585 KB    |            |   0%
# cryptography-2.3.1   | 585 KB    | ########## | 100%
#
# tensorflow-2.0.0     | 3 KB      |            |   0%
# tensorflow-2.0.0     | 3 KB      | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | #7         |  17%
# icu-58.2             | 22.7 MB   | #####3     |  53%
# icu-58.2             | 22.7 MB   | ########1  |  82%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# bzip2-1.0.8          | 105 KB    |            |   0%
# bzip2-1.0.8          | 105 KB    | ########## | 100%
#
# libogg-1.3.2         | 205 KB    |            |   0%
# libogg-1.3.2         | 205 KB    | ########## | 100%
#
# resampy-0.2.2        | 332 KB    |            |   0%
# resampy-0.2.2        | 332 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# markdown-3.3.2       | 123 KB    |            |   0%
# markdown-3.3.2       | 123 KB    | ########## | 100%
#
# libvorbis-1.3.7      | 549 KB    |            |   0%
# libvorbis-1.3.7      | 549 KB    | ########## | 100%
#
# pyyaml-5.3.1         | 191 KB    |            |   0%
# pyyaml-5.3.1         | 191 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# urllib3-1.25.11      | 93 KB     |            |   0%
# urllib3-1.25.11      | 93 KB     | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ######5    |  66%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
# pillow-6.2.1         | 640 KB    |            |   0%
# pillow-6.2.1         | 640 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# matplotlib-base-3.2. | 7.1 MB    |            |   0%
# matplotlib-base-3.2. | 7.1 MB    | ####3      |  44%
# matplotlib-base-3.2. | 7.1 MB    | ########## | 100%
#
# astor-0.8.1          | 45 KB     |            |   0%
# astor-0.8.1          | 45 KB     | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ######3    |  63%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# werkzeug-0.16.1      | 256 KB    |            |   0%
# werkzeug-0.16.1      | 256 KB    | ########## | 100%
#
# keras-preprocessing- | 36 KB     |            |   0%
# keras-preprocessing- | 36 KB     | ########## | 100%
#
# tbb-2020.3           | 1.4 MB    |            |   0%
# tbb-2020.3           | 1.4 MB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# google-pasta-0.2.0   | 44 KB     |            |   0%
# google-pasta-0.2.0   | 44 KB     | ########## | 100%
#
# keras-applications-1 | 30 KB     |            |   0%
# keras-applications-1 | 30 KB     | ########## | 100%
#
# libsndfile-1.0.29    | 534 KB    |            |   0%
# libsndfile-1.0.29    | 534 KB    | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# pooch-1.3.0          | 40 KB     |            |   0%
# pooch-1.3.0          | 40 KB     | ########## | 100%
#
# keras-2.3.1          | 12 KB     |            |   0%
# keras-2.3.1          | 12 KB     | ########## | 100%
#
# hdf5-1.10.6          | 4.8 MB    |            |   0%
# hdf5-1.10.6          | 4.8 MB    | ########## | 100%
#
# grpcio-1.14.1        | 1.0 MB    |            |   0%
# grpcio-1.14.1        | 1.0 MB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# idna-2.10            | 56 KB     |            |   0%
# idna-2.10            | 56 KB     | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# lame-3.100           | 502 KB    |            |   0%
# lame-3.100           | 502 KB    | ########## | 100%
#
# protobuf-3.13.0.1    | 698 KB    |            |   0%
# protobuf-3.13.0.1    | 698 KB    | ########## | 100%
#
# pyopenssl-19.0.0     | 82 KB     |            |   0%
# pyopenssl-19.0.0     | 82 KB     | ########## | 100%
#
# cffi-1.14.0          | 225 KB    |            |   0%
# cffi-1.14.0          | 225 KB    | ########## | 100%
#
# h5py-2.10.0          | 1.1 MB    |            |   0%
# h5py-2.10.0          | 1.1 MB    | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# asn1crypto-1.4.0     | 77 KB     |            |   0%
# asn1crypto-1.4.0     | 77 KB     | ########## | 100%
#
# requests-2.24.0      | 54 KB     |            |   0%
# requests-2.24.0      | 54 KB     | ########## | 100%
#
# tensorboard-2.0.0    | 3.3 MB    |            |   0%
# tensorboard-2.0.0    | 3.3 MB    | ########## | 100%
#
# libprotobuf-3.13.0.1 | 2.3 MB    |            |   0%
# libprotobuf-3.13.0.1 | 2.3 MB    | ########6  |  86%
# libprotobuf-3.13.0.1 | 2.3 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# audioread-2.1.9      | 32 KB     |            |   0%
# audioread-2.1.9      | 32 KB     | ########## | 100%
#
# c-ares-1.16.1        | 112 KB    |            |   0%
# c-ares-1.16.1        | 112 KB    | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# matplotlib-3.2.1     | 20 KB     |            |   0%
# matplotlib-3.2.1     | 20 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# wrapt-1.12.1         | 49 KB     |            |   0%
# wrapt-1.12.1         | 49 KB     | ########## | 100%
#
# libflac-1.3.3        | 517 KB    |            |   0%
# libflac-1.3.3        | 517 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# termcolor-1.1.0      | 7 KB      |            |   0%
# termcolor-1.1.0      | 7 KB      | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 5          |   6%
# qt-5.9.6             | 86.7 MB   | #4         |  14%
# qt-5.9.6             | 86.7 MB   | ##3        |  23%
# qt-5.9.6             | 86.7 MB   | ###        |  31%
# qt-5.9.6             | 86.7 MB   | ###7       |  37%
# qt-5.9.6             | 86.7 MB   | ####4      |  45%
# qt-5.9.6             | 86.7 MB   | #####1     |  51%
# qt-5.9.6             | 86.7 MB   | #####7     |  57%
# qt-5.9.6             | 86.7 MB   | ######3    |  63%
# qt-5.9.6             | 86.7 MB   | ######8    |  69%
# qt-5.9.6             | 86.7 MB   | #######5   |  75%
# qt-5.9.6             | 86.7 MB   | ########2  |  82%
# qt-5.9.6             | 86.7 MB   | #########  |  90%
# qt-5.9.6             | 86.7 MB   | #########9 |  99%
#
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# numba-0.51.2         | 3.7 MB    |            |   0%
# numba-0.51.2         | 3.7 MB    | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# gast-0.2.2           | 138 KB    |            |   0%
# gast-0.2.2           | 138 KB    | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# librosa-0.8.0        | 145 KB    |            |   0%
# librosa-0.8.0        | 145 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# gnutls-3.6.5         | 1.9 MB    |            |   0%
# gnutls-3.6.5         | 1.9 MB    | ########## | 100%
#
# importlib-metadata-2 | 35 KB     |            |   0%
# importlib-metadata-2 | 35 KB     | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# tensorflow-base-2.0. | 100.9 MB  |            |   0%
# tensorflow-base-2.0. | 100.9 MB  | 2          |   3%
# tensorflow-base-2.0. | 100.9 MB  | #          |  11%
# tensorflow-base-2.0. | 100.9 MB  | #7         |  17%
# tensorflow-base-2.0. | 100.9 MB  | ##3        |  23%
# tensorflow-base-2.0. | 100.9 MB  | ##8        |  28%
# tensorflow-base-2.0. | 100.9 MB  | ###4       |  34%
# tensorflow-base-2.0. | 100.9 MB  | ####1      |  42%
# tensorflow-base-2.0. | 100.9 MB  | ####9      |  49%
# tensorflow-base-2.0. | 100.9 MB  | #####5     |  55%
# tensorflow-base-2.0. | 100.9 MB  | ######1    |  62%
# tensorflow-base-2.0. | 100.9 MB  | ######8    |  69%
# tensorflow-base-2.0. | 100.9 MB  | #######6   |  76%
# tensorflow-base-2.0. | 100.9 MB  | ########4  |  84%
# tensorflow-base-2.0. | 100.9 MB  | #########1 |  91%
# tensorflow-base-2.0. | 100.9 MB  | #########8 |  98%
# tensorflow-base-2.0. | 100.9 MB  | ########## | 100%
#
# libvpx-1.7.0         | 2.4 MB    |            |   0%
# libvpx-1.7.0         | 2.4 MB    | ########## | 100%
#
# absl-py-0.10.0       | 168 KB    |            |   0%
# absl-py-0.10.0       | 168 KB    | ########## | 100%
#
# x264-1!157.20191217  | 2.5 MB    |            |   0%
# x264-1!157.20191217  | 2.5 MB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #########3 |  94%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# appdirs-1.4.4        | 13 KB     |            |   0%
# appdirs-1.4.4        | 13 KB     | ########## | 100%
#
# pysoundfile-0.10.3.p | 23 KB     |            |   0%
# pysoundfile-0.10.3.p | 23 KB     | ########## | 100%
#
# opt_einsum-3.1.0     | 54 KB     |            |   0%
# opt_einsum-3.1.0     | 54 KB     | ########## | 100%
#
# libllvm10-10.0.1     | 26.5 MB   |            |   0%
# libllvm10-10.0.1     | 26.5 MB   | #4         |  15%
# libllvm10-10.0.1     | 26.5 MB   | ####3      |  43%
# libllvm10-10.0.1     | 26.5 MB   | #######3   |  73%
# libllvm10-10.0.1     | 26.5 MB   | ########## | 100%
#
# nettle-3.4.1         | 6.7 MB    |            |   0%
# nettle-3.4.1         | 6.7 MB    | #######9   |  80%
# nettle-3.4.1         | 6.7 MB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | ########1  |  81%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# pycparser-2.20       | 94 KB     |            |   0%
# pycparser-2.20       | 94 KB     | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# gettext-0.19.8.1     | 3.7 MB    |            |   0%
# gettext-0.19.8.1     | 3.7 MB    | ########## | 100%
#
# openh264-2.1.0       | 1.5 MB    |            |   0%
# openh264-2.1.0       | 1.5 MB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ###1       |  32%
# scipy-1.5.2          | 18.5 MB   | #######2   |  72%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# pysocks-1.7.1        | 30 KB     |            |   0%
# pysocks-1.7.1        | 30 KB     | ########## | 100%
#
# libopus-1.3.1        | 570 KB    |            |   0%
# libopus-1.3.1        | 570 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# keras-base-2.3.1     | 599 KB    |            |   0%
# keras-base-2.3.1     | 599 KB    | ########## | 100%
#
# gmp-6.1.2            | 744 KB    |            |   0%
# gmp-6.1.2            | 744 KB    | ########## | 100%
#
# yaml-0.2.5           | 87 KB     |            |   0%
# yaml-0.2.5           | 87 KB     | ########## | 100%
#
# _tflow_select-2.3.0  | 2 KB      |            |   0%
# _tflow_select-2.3.0  | 2 KB      | ########## | 100%
#
# ffmpeg-4.2.2         | 80.5 MB   |            |   0%
# ffmpeg-4.2.2         | 80.5 MB   | 5          |   5%
# ffmpeg-4.2.2         | 80.5 MB   | #3         |  13%
# ffmpeg-4.2.2         | 80.5 MB   | ##2        |  22%
# ffmpeg-4.2.2         | 80.5 MB   | ##9        |  29%
# ffmpeg-4.2.2         | 80.5 MB   | ###8       |  39%
# ffmpeg-4.2.2         | 80.5 MB   | ####7      |  48%
# ffmpeg-4.2.2         | 80.5 MB   | #####5     |  56%
# ffmpeg-4.2.2         | 80.5 MB   | ######4    |  64%
# ffmpeg-4.2.2         | 80.5 MB   | #######1   |  72%
# ffmpeg-4.2.2         | 80.5 MB   | ########1  |  82%
# ffmpeg-4.2.2         | 80.5 MB   | #########  |  90%
# ffmpeg-4.2.2         | 80.5 MB   | #########9 | 100%
#
# ffmpeg-4.2.2         | 80.5 MB   | ########## | 100%
#
# packaging-20.4       | 35 KB     |            |   0%
# packaging-20.4       | 35 KB     | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #5         |  16%
# python-3.6.2         | 27.0 MB   | ####2      |  42%
# python-3.6.2         | 27.0 MB   | ######7    |  68%
# python-3.6.2         | 27.0 MB   | ########7  |  88%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.20.0
#   Downloading azureml_defaults-1.20.0-py3-none-any.whl (3.1 kB)
# Collecting tensorflow==2.4.0
#   Downloading tensorflow-2.4.0-cp36-cp36m-manylinux2010_x86_64.whl (394.7 MB)
# Requirement already satisfied, skipping upgrade: werkzeug<=1.0.1,>=0.16.1 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (0.16.1)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-core~=1.20.0
#   Downloading azureml_core-1.20.0.post1-py3-none-any.whl (2.1 MB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.20.0
#   Downloading azureml_dataset_runtime-1.20.0-py3-none-any.whl (3.4 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied, skipping upgrade: protobuf>=3.9.2 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from tensorflow==2.4.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 2)) (3.13.0)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied, skipping upgrade: h5py~=2.10.0 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from tensorflow==2.4.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 2)) (2.10.0)
# Collecting tensorboard~=2.4
#   Downloading tensorboard-2.4.1-py3-none-any.whl (10.6 MB)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied, skipping upgrade: termcolor~=1.1.0 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from tensorflow==2.4.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied, skipping upgrade: wheel~=0.35 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from tensorflow==2.4.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 2)) (0.35.1)
# Requirement already satisfied, skipping upgrade: six~=1.15.0 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from tensorflow==2.4.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied, skipping upgrade: absl-py~=0.10 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from tensorflow==2.4.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 2)) (0.10.0)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Requirement already satisfied, skipping upgrade: wrapt~=1.12.1 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from tensorflow==2.4.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 2)) (1.12.1)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp36-cp36m-manylinux2014_x86_64.whl (3.8 MB)
# Requirement already satisfied, skipping upgrade: google-pasta~=0.2 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from tensorflow==2.4.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 2)) (0.2.0)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0rc0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Requirement already satisfied, skipping upgrade: pyopenssl<20.0.0 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (19.0.0)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Requirement already satisfied, skipping upgrade: urllib3>=1.23 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (1.25.11)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied, skipping upgrade: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (2.3.1)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.0.0-py2.py3-none-any.whl (1.1 MB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied, skipping upgrade: requests>=2.19.1 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (2.24.0)
# Collecting docker
#   Downloading docker-4.4.3-py2.py3-none-any.whl (146 kB)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting azureml-dataprep<2.8.0a,>=2.7.0a
#   Downloading azureml_dataprep-2.7.4-py3-none-any.whl (39.4 MB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Requirement already satisfied, skipping upgrade: setuptools in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from protobuf>=3.9.2->tensorflow==2.4.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 2)) (50.3.0.post20201006)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.2-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.27.0-py2.py3-none-any.whl (135 kB)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from tensorboard~=2.4->tensorflow==2.4.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 2)) (3.3.2)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (2020.6.20)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from jsonpickle->azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (2.0.0)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied, skipping upgrade: idna>=2.1 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (2.10)
# Requirement already satisfied, skipping upgrade: asn1crypto>=0.21.0 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.7 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (1.14.0)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (3.0.4)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-rslex<1.6.0a,>=1.5.0dev0
#   Downloading azureml_dataprep_rslex-1.5.0-cp36-cp36m-manylinux2010_x86_64.whl (8.1 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<28.0.0,>=27.0.0
#   Downloading azureml_dataprep_native-27.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.7.1-py3-none-any.whl (36 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.1-py3-none-any.whl (12 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle->azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (3.3.1)
# Requirement already satisfied, skipping upgrade: pycparser in /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.uxrwvcu1.requirements.txt (line 1)) (2.20)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.11.0-py2.py3-none-any.whl (127 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.9.0-py2.py3-none-any.whl (59 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: json-logging-py, liac-arff, fusepy
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=c84b38b9c1e2b8b20e489ec7852c1c4e3b7c9aec03fae97370bd33b1953e29a2
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=c833d644545748aa4f6a945e82a207ff139be142cd8044ba7a6d3856b10c88e0
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=7ef1597c664a5dc61cf986f2463324ac05077eb32fe712d9171672b6959211a7
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built json-logging-py liac-arff fusepy
# Installing collected packages: applicationinsights, PyJWT, adal, oauthlib, requests-oauthlib, isodate, msrest, msrestazure, azure-common, azure-graphrbac, pyasn1, ndg-httpsclient, ruamel.yaml.clib, ruamel.yaml, azure-mgmt-storage, jsonpickle, azure-mgmt-authorization, backports.weakref, backports.tempfile, azure-mgmt-containerregistry, jmespath, pathspec, pytz, azure-mgmt-keyvault, azure-mgmt-resource, jeepney, SecretStorage, contextlib2, websocket-client, docker, azureml-core, click, MarkupSafe, Jinja2, itsdangerous, flask, numpy, pandas, liac-arff, dill, azureml-model-management-sdk, distro, dotnetcore2, azureml-dataprep-rslex, cloudpickle, azureml-dataprep-native, msal, portalocker, msal-extensions, azure-core, azure-identity, azureml-dataprep, pyarrow, fusepy, azureml-dataset-runtime, configparser, json-logging-py, gunicorn, azureml-defaults, gast, pyasn1-modules, rsa, cachetools, google-auth, google-auth-oauthlib, grpcio, tensorboard-plugin-wit, tensorboard, astunparse, keras-preprocessing, opt-einsum, typing-extensions, tensorflow-estimator, flatbuffers, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.1
#     Uninstalling numpy-1.19.1:
#       Successfully uninstalled numpy-1.19.1
#   Attempting uninstall: gast
#     Found existing installation: gast 0.2.2
#     Uninstalling gast-0.2.2:
#       Successfully uninstalled gast-0.2.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.14.1
#     Uninstalling grpcio-1.14.1:
#       Successfully uninstalled grpcio-1.14.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.0.0
#     Uninstalling tensorboard-2.0.0:
#       Successfully uninstalled tensorboard-2.0.0
#   Attempting uninstall: keras-preprocessing
#     Found existing installation: Keras-Preprocessing 1.1.0
#     Uninstalling Keras-Preprocessing-1.1.0:
#       Successfully uninstalled Keras-Preprocessing-1.1.0
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt-einsum 3.1.0
#     Uninstalling opt-einsum-3.1.0:
#       Successfully uninstalled opt-einsum-3.1.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.0.0
#     Uninstalling tensorflow-estimator-2.0.0:
#       Successfully uninstalled tensorflow-estimator-2.0.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.0.0
#     Uninstalling tensorflow-2.0.0:
#       Successfully uninstalled tensorflow-2.0.0
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.1 adal-1.2.6 applicationinsights-0.11.9 astunparse-1.6.3 azure-common-1.1.26 azure-core-1.11.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.20.0.post1 azureml-dataprep-2.7.4 azureml-dataprep-native-27.0.0 azureml-dataprep-rslex-1.5.0 azureml-dataset-runtime-1.20.0 azureml-defaults-1.20.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cachetools-4.2.1 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 dill-0.3.3 distro-1.5.0 docker-4.4.3 dotnetcore2-2.1.20 flask-1.0.3 flatbuffers-1.12 fusepy-3.0.1 gast-0.3.3 google-auth-1.27.0 google-auth-oauthlib-0.4.2 grpcio-1.32.0 gunicorn-19.9.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 keras-preprocessing-1.1.2 liac-arff-2.5.0 msal-1.9.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.19.5 oauthlib-3.1.0 opt-einsum-3.3.0 pandas-1.1.5 pathspec-0.8.1 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pytz-2021.1 requests-oauthlib-1.3.0 rsa-4.7.1 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 tensorboard-2.4.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.4.0 tensorflow-estimator-2.4.0 typing-extensions-3.7.4.3 websocket-client-0.57.0
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 1c6cf3d53c82
#  ---> fd3a44fa46fe
# Step 9/18 : ENV PATH /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/bin:$PATH
#  ---> Running in 6a613b458b85
# Removing intermediate container 6a613b458b85
#  ---> 5ce32ead4574
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> da0d11c0f3ae
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 3fd75f406b58
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0
#  ---> Running in 9b11c7f73ae2
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 9b11c7f73ae2
#  ---> 556637244a7b
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0
#  ---> Running in dbb495d80a99
# Removing intermediate container dbb495d80a99
#  ---> ac92e5a6a038
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_d66b695a90f0d7c9f18c84a75fb1fbb0/lib:$LD_LIBRARY_PATH
#  ---> Running in ea14a96ccd85
# Removing intermediate container ea14a96ccd85
#  ---> f3823d4125c5
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 50ab64e459da
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in cb0112007d50
# Removing intermediate container cb0112007d50
#  ---> aa5100e1519f
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 107381ab4268
# Removing intermediate container 107381ab4268
#  ---> d21b993d40ba
# Step 18/18 : CMD ["bash"]
#  ---> Running in 2140989593ec
# Removing intermediate container 2140989593ec
#  ---> e92631c79ec2
# Successfully built e92631c79ec2
# Successfully tagged aiforgoodgp1.azurecr.io/azureml/azureml_ad62db7f7c1311ccdaef5041bbb61fe8:latest
# 2021/02/23 22:46:46 Successfully executed container: acb_step_0
# 2021/02/23 22:46:46 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/02/23 22:46:46 Pushing image: aiforgoodgp1.azurecr.io/azureml/azureml_ad62db7f7c1311ccdaef5041bbb61fe8:latest, attempt 1
# The push refers to repository [aiforgoodgp1.azurecr.io/azureml/azureml_ad62db7f7c1311ccdaef5041bbb61fe8]
# acd2259beb13: Preparing
# 21ef6e2e31a5: Preparing
# a4042d2da092: Preparing
# 9f12516fe4bd: Preparing
# b9813c08ad63: Preparing
# 68e66ace6337: Preparing
# 348564161c89: Preparing
# 85821fffef2a: Preparing
# a70173f761c7: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# 68e66ace6337: Waiting
# 348564161c89: Waiting
# 85821fffef2a: Waiting
# a70173f761c7: Waiting
# fc2b9863058f: Waiting
# c9fd473f5354: Waiting
# f449d8429d6e: Waiting
# 8547178b7afb: Waiting
# cbb89d0b53de: Waiting
# 1a1a19626b20: Waiting
# 5b7dc8292d9b: Waiting
# 088c5f014be3: Waiting
# 0c7d6f1219f0: Waiting
# bbc674332e2e: Waiting
# e342e7653d41: Waiting
# da2785b7bb16: Waiting
# a4042d2da092: Pushed
# 9f12516fe4bd: Pushed
# acd2259beb13: Pushed
# 21ef6e2e31a5: Pushed
# 68e66ace6337: Pushed
# 85821fffef2a: Pushed
# 348564161c89: Pushed
# c9fd473f5354: Layer already exists
# f449d8429d6e: Layer already exists
# cbb89d0b53de: Layer already exists
# 088c5f014be3: Layer already exists
# 0c7d6f1219f0: Layer already exists
# 8547178b7afb: Layer already exists
# e342e7653d41: Layer already exists
# a70173f761c7: Pushed
# 5b7dc8292d9b: Layer already exists
# bbc674332e2e: Layer already exists
# 1a1a19626b20: Layer already exists
# da2785b7bb16: Layer already exists
# fc2b9863058f: Layer already exists
#
# b9813c08ad63: Pushed
# latest: digest: sha256:eab7ce44a55379016d696ffec79551a38dedd1173e5d759bee9e3905081e6122 size: 4722
# 2021/02/23 22:51:03 Successfully pushed image: aiforgoodgp1.azurecr.io/azureml/azureml_ad62db7f7c1311ccdaef5041bbb61fe8:latest
# 2021/02/23 22:51:03 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 571.480952)
# 2021/02/23 22:51:03 Populating digests for step ID: acb_step_0...
# 2021/02/23 22:51:05 Successfully populated digests for step ID: acb_step_0
# 2021/02/23 22:51:05 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 256.472457)
# 2021/02/23 22:51:05 The following dependencies were found:
# 2021/02/23 22:51:05
# - image:
#     registry: aiforgoodgp1.azurecr.io
#     repository: azureml/azureml_ad62db7f7c1311ccdaef5041bbb61fe8
#     tag: latest
#     digest: sha256:eab7ce44a55379016d696ffec79551a38dedd1173e5d759bee9e3905081e6122
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
#
# Run ID: ca4 was successful after 13m56s
# Image Build Status: Succeeded

# %%
inference_config = InferenceConfig(entry_script="score.py", environment=myenv)

aciconfig = AciWebservice.deploy_configuration(cpu_cores=2,
                                               auth_enabled=True, # this flag generates API keys to secure access
                                               memory_gb=2,
                                               tags={'name': 'aiforgoodp15', 'framework': 'Keras'},
                                               description='Keras MLP on wav')

registered_model = Model(ws,'aiforgoodp15')

service = Model.deploy(workspace=ws, 
                           name='aiforgoodp15v6', 
                           models=[registered_model], 
                           inference_config=inference_config, 
                           deployment_config=aciconfig)

service.wait_for_deployment(True)
print(service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running..........................................
# Succeeded
# ACI service creation operation finished, operation "Succeeded"
# Healthy

# %% [markdown]
# **Tip: If something goes wrong with the deployment, the first thing to look at is the logs from the service by running the following command:**

# %%
print(service.get_logs())

# %% [markdown]
# This is the scoring web service endpoint:

# %%
print(service.scoring_uri)
# Out:
# http://6c9792fc-56c3-4631-8fa1-35013661721e.eastus.azurecontainer.io/score

# %% [markdown]
# ### Test the deployed model
# Let's test the deployed model. Pick 30 random samples from the test set, and send it to the web service hosted in ACI. Note here we are using the `run` API in the SDK to invoke the service. You can also make raw HTTP calls using any HTTP tool such as curl.
#
# After the invocation, we print the returned predictions and plot them along with the input images. Use red font color and inversed image (white on black) to highlight the misclassified samples. Note since the model accuracy is pretty high, you might have to run the below cell a few times before you can see a misclassified sample.

# %% [markdown]
# We can retrieve the API keys used for accessing the HTTP endpoint.

# %%
# Retrieve the API keys. Two keys were generated.
key1, Key2 = service.get_keys()
print(key1)
# Out:
# mwBrQDOExB6buHYjXHesgr1NRIvkBv4p

# %% [markdown]
# We can now send construct raw HTTP request and send to the service. Don't forget to add key to the HTTP header.

# %%
import requests

audio_data    = './nn01a_20180203_1230-Copy1.wav'
print(type(audio_data))
headers = {'Content-Type':'audio/wav','Content-Disposition':'attachment; filename=audio_data ', 'Authorization': 'Bearer ' + key1}
resp = requests.post(service.scoring_uri, headers=headers)
resp = requests.post(service.scoring_uri, audio_data, headers=headers)

print("POST to url", service.scoring_uri)
print(resp)
# Out:
# <class 'str'>
# POST to url http://6c9792fc-56c3-4631-8fa1-35013661721e.eastus.azurecontainer.io/score
# <Response [415]>

# %% [markdown]
# Let's look at the workspace after the web service was deployed. You should see
# * a registered model named 'keras-mlp-mnist' and with the id 'model:1'
# * a webservice called 'keras-mnist-svc' with some scoring URL

# %%
model = ws.models['keras-mlp-mnist']
print("Model: {}, ID: {}".format('keras-mlp-mnist', model.id))
    
webservice = ws.webservices['keras-mnist-svc']
print("Webservice: {}, scoring URI: {}".format('keras-mnist-svc', webservice.scoring_uri))

# %% [markdown]
# ## Clean up
# You can delete the ACI deployment with a simple delete API call.

# %%
service.delete()
